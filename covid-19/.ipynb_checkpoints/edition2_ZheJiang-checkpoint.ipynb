# %% [markdown]
# ## 说明
# 该版本为上一版本对其他省份的拓展，该版本对浙江省的数据进行分析

# %% [markdown]
# # 环境准备

# %%
# !pip install jstyleson folium
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: jstyleson in d:\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: folium in d:\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: jinja2>=2.9 in d:\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from folium) (1.19.2)
# Requirement already satisfied: branca>=0.3.0 in d:\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests->folium) (2020.6.20)

# %% [markdown]
# # 数据扫描

# %%
# CSV读取
import csv

# 市级以上行政区列表
city_list = set()

with open('china_city_list.csv') as city_list_csv:
    reader = csv.DictReader(city_list_csv)
    for row in reader:
        city_list.add(row['City'])
        city_list.add(row['City_Admaster'])
        city_list.add(row['Province'])
        
city_list
# Out:
# {'七台河',
#  '七台河市',
#  '三亚',
#  '三亚市',
#  '三明',
#  '三明市',
#  '三门峡',
#  '三门峡市',
#  '上海',
#  '上海市',
#  '上饶',
#  '上饶市',
#  '东莞',
#  '东莞市',
#  '东营',
#  '东营市',
#  '中卫',
#  '中卫市',
#  '中山',
#  '中山市',
#  '临汾',
#  '临汾市',
#  '临沂',
#  '临沂市',
#  '临沧',
#  '临沧市',
#  '丹东',
#  '丹东市',
#  '丽水',
#  '丽水市',
#  '丽江',
#  '丽江市',
#  '乌兰察布',
#  '乌兰察布市',
#  '乌海',
#  '乌海市',
#  '乌鲁木齐',
#  '乌鲁木齐市',
#  '乐山',
#  '乐山市',
#  '九江',
#  '九江市',
#  '云南',
#  '云浮',
#  '云浮市',
#  '亳州',
#  '亳州市',
#  '伊春',
#  '伊春市',
#  '伊犁',
#  '伊犁哈萨克自治州',
#  '佛山',
#  '佛山市',
#  '佳木斯',
#  '佳木斯市',
#  '保定',
#  '保定市',
#  '保山',
#  '保山市',
#  '信阳',
#  '信阳市',
#  '儋州',
#  '儋州市',
#  '克孜勒苏柯尔克孜',
#  '克孜勒苏柯尔克孜自治州',
#  '克拉玛依',
#  '克拉玛依市',
#  '六安',
#  '六安市',
#  '六盘水',
#  '六盘水市',
#  '兰州',
#  '兰州市',
#  '兴安盟',
#  '内江',
#  '内江市',
#  '内蒙古',
#  '凉山',
#  '凉山彝族自治州',
#  '包头',
#  '包头市',
#  '北京',
#  '北京市',
#  '北海',
#  '北海市',
#  '十堰',
#  '十堰市',
#  '南京',
#  '南京市',
#  '南充',
#  '南充市',
#  '南宁',
#  '南宁市',
#  '南平',
#  '南平市',
#  '南昌',
#  '南昌市',
#  '南通',
#  '南通市',
#  '南阳',
#  '南阳市',
#  '博尔塔拉',
#  '博尔塔拉蒙古自治州',
#  '厦门',
#  '厦门市',
#  '双鸭山',
#  '双鸭山市',
#  '台州',
#  '台州市',
#  '合肥',
#  '合肥市',
#  '吉安',
#  '吉安市',
#  '吉林',
#  '吉林市',
#  '吐鲁番',
#  '吐鲁番地区',
#  '吐鲁番市',
#  '吕梁',
#  '吕梁市',
#  '吴忠',
#  '吴忠市',
#  '周口',
#  '周口市',
#  '呼伦贝尔',
#  '呼伦贝尔市',
#  '呼和浩特',
#  '呼和浩特市',
#  '和田',
#  '和田地区',
#  '咸宁',
#  '咸宁市',
#  '咸阳',
#  '咸阳市',
#  '哈密',
#  '哈密地区',
#  '哈尔滨',
#  '哈尔滨市',
#  '唐山',
#  '唐山市',
#  '商丘',
#  '商丘市',
#  '商洛',
#  '商洛市',
#  '喀什',
#  '喀什地区',
#  '嘉兴',
#  '嘉兴市',
#  '嘉峪关',
#  '嘉峪关市',
#  '四川',
#  '四平',
#  '四平市',
#  '固原',
#  '固原市',
#  '塔城',
#  '塔城地区',
#  '大兴安岭',
#  '大兴安岭地区',
#  '大同',
#  '大同市',
#  '大庆',
#  '大庆市',
#  '大理',
#  '大理白族自治州',
#  '大连',
#  '大连市',
#  '天水',
#  '天水市',
#  '天津',
#  '天津市',
#  '太原',
#  '太原市',
#  '威海',
#  '威海市',
#  '娄底',
#  '娄底市',
#  '孝感',
#  '孝感市',
#  '宁夏',
#  '宁德',
#  '宁德市',
#  '宁波',
#  '宁波市',
#  '安庆',
#  '安庆市',
#  '安康',
#  '安康市',
#  '安徽',
#  '安阳',
#  '安阳市',
#  '安顺',
#  '安顺市',
#  '定西',
#  '定西市',
#  '宜宾',
#  '宜宾市',
#  '宜昌',
#  '宜昌市',
#  '宜春',
#  '宜春市',
#  '宝鸡',
#  '宝鸡市',
#  '宣城',
#  '宣城市',
#  '宿州',
#  '宿州市',
#  '宿迁',
#  '宿迁市',
#  '山东',
#  '山南',
#  '山南地区',
#  '山南市',
#  '山西',
#  '岳阳',
#  '岳阳市',
#  '崇左',
#  '崇左市',
#  '巢湖',
#  '巢湖市',
#  '巴中',
#  '巴中市',
#  '巴彦淖尔',
#  '巴彦淖尔市',
#  '巴音郭楞',
#  '巴音郭楞蒙古自治州',
#  '常州',
#  '常州市',
#  '常德',
#  '常德市',
#  '平凉',
#  '平凉市',
#  '平顶山',
#  '平顶山市',
#  '广东',
#  '广元',
#  '广元市',
#  '广安',
#  '广安市',
#  '广州',
#  '广州市',
#  '广西',
#  '庆阳',
#  '庆阳市',
#  '廊坊',
#  '廊坊市',
#  '延安',
#  '延安市',
#  '延边',
#  '延边朝鲜族自治州',
#  '开封',
#  '开封市',
#  '张家口',
#  '张家口市',
#  '张家界',
#  '张家界市',
#  '张掖',
#  '张掖市',
#  '徐州',
#  '徐州市',
#  '德宏',
#  '德宏傣族景颇族自治州',
#  '德州',
#  '德州市',
#  '德阳',
#  '德阳市',
#  '忻州',
#  '忻州市',
#  '怀化',
#  '怀化市',
#  '怒江',
#  '怒江傈僳族自治州',
#  '恩施',
#  '恩施土家族苗族自治州',
#  '惠州',
#  '惠州市',
#  '成都',
#  '成都市',
#  '扬州',
#  '扬州市',
#  '承德',
#  '承德市',
#  '抚州',
#  '抚州市',
#  '抚顺',
#  '抚顺市',
#  '拉萨',
#  '拉萨市',
#  '揭阳',
#  '揭阳市',
#  '攀枝花',
#  '攀枝花市',
#  '文山',
#  '文山壮族苗族自治州',
#  '新乡',
#  '新乡市',
#  '新余',
#  '新余市',
#  '新疆',
#  '无锡',
#  '无锡市',
#  '日喀则',
#  '日喀则地区',
#  '日喀则市',
#  '日照',
#  '日照市',
#  '昆明',
#  '昆明市',
#  '昌吉',
#  '昌吉回族自治州',
#  '昌都',
#  '昌都地区',
#  '昌都市',
#  '昭通',
#  '昭通市',
#  '晋中',
#  '晋中市',
#  '晋城',
#  '晋城市',
#  '普洱',
#  '普洱市',
#  '景德镇',
#  '景德镇市',
#  '曲靖',
#  '曲靖市',
#  '朔州',
#  '朔州市',
#  '朝阳',
#  '朝阳市',
#  '本溪',
#  '本溪市',
#  '来宾',
#  '来宾市',
#  '杭州',
#  '杭州市',
#  '松原',
#  '松原市',
#  '林芝',
#  '林芝地区',
#  '林芝市',
#  '果洛',
#  '果洛藏族自治州',
#  '枣庄',
#  '枣庄市',
#  '柳州',
#  '柳州市',
#  '株洲',
#  '株洲市',
#  '桂林',
#  '桂林市',
#  '梅州',
#  '梅州市',
#  '梧州',
#  '梧州市',
#  '楚雄',
#  '楚雄彝族自治州',
#  '榆林',
#  '榆林市',
#  '武威',
#  '武威市',
#  '武汉',
#  '武汉市',
#  '毕节',
#  '毕节地区',
#  '毕节市',
#  '永州',
#  '永州市',
#  '汉中',
#  '汉中市',
#  '汕头',
#  '汕头市',
#  '汕尾',
#  '汕尾市',
#  '江苏',
#  '江西',
#  '江门',
#  '江门市',
#  '池州',
#  '池州市',
#  '沈阳',
#  '沈阳市',
#  '沧州',
#  '沧州市',
#  '河北',
#  '河南',
#  '河池',
#  '河池市',
#  '河源',
#  '河源市',
#  '泉州',
#  '泉州市',
#  '泰安',
#  '泰安市',
#  '泰州',
#  '泰州市',
#  '泸州',
#  '泸州市',
#  '洛阳',
#  '洛阳市',
#  '济南',
#  '济南市',
#  '济宁',
#  '济宁市',
#  '浙江',
#  '海东',
#  '海东地区',
#  '海东市',
#  '海北',
#  '海北藏族自治州',
#  '海南',
#  '海南藏族自治州',
#  '海口',
#  '海口市',
#  '海西',
#  '海西蒙古族藏族自治州',
#  '淄博',
#  '淄博市',
#  '淮北',
#  '淮北市',
#  '淮南',
#  '淮南市',
#  '淮安',
#  '深圳',
#  '深圳市',
#  '清远',
#  '清远市',
#  '温州',
#  '温州市',
#  '渭南',
#  '渭南市',
#  '湖北',
#  '湖南',
#  '湖州',
#  '湖州市',
#  '湘潭',
#  '湘潭市',
#  '湘西',
#  '湘西土家族苗族自治州',
#  '湛江',
#  '湛江市',
#  '滁州',
#  '滁州市',
#  '滨州',
#  '滨州市',
#  '漯河',
#  '漯河市',
#  '漳州',
#  '漳州市',
#  '潍坊',
#  '潍坊市',
#  '潮州',
#  '潮州市',
#  '濮阳',
#  '濮阳市',
#  '烟台',
#  '烟台市',
#  '焦作',
#  '焦作市',
#  '牡丹江',
#  '牡丹江市',
#  '玉林',
#  '玉林市',
#  '玉树',
#  '玉树藏族自治州',
#  '玉溪',
#  '玉溪市',
#  '珠海',
#  '珠海市',
#  '甘南',
#  '甘南藏族自治州',
#  '甘孜',
#  '甘孜藏族自治州',
#  '甘肃',
#  '白城',
#  '白城市',
#  '白山',
#  '白山市',
#  '白银',
#  '白银市',
#  '百色',
#  '百色市',
#  '益阳',
#  '益阳市',
#  '盐城',
#  '盐城市',
#  '盘锦',
#  '盘锦市',
#  '眉山',
#  '眉山市',
#  '石嘴山',
#  '石嘴山市',
#  '石家庄',
#  '石家庄市',
#  '福州',
#  '福州市',
#  '福建',
#  '秦皇岛',
#  '秦皇岛市',
#  '红河',
#  '红河哈尼族彝族自治州',
#  '绍兴',
#  '绍兴市',
#  '绥化',
#  '绥化市',
#  '绵阳',
#  '绵阳市',
#  '聊城',
#  '聊城市',
#  '肇庆',
#  '肇庆市',
#  '自贡',
#  '自贡市',
#  '舟山',
#  '舟山市',
#  '芜湖',
#  '芜湖市',
#  '苏州',
#  '苏州市',
#  '茂名',
#  '茂名市',
#  '荆州',
#  '荆州市',
#  '荆门',
#  '荆门市',
#  '莆田',
#  '莆田市',
#  '莱芜',
#  '莱芜市',
#  '菏泽',
#  '菏泽市',
#  '萍乡',
#  '萍乡市',
#  '营口',
#  '营口市',
#  '葫芦岛',
#  '葫芦岛市',
#  '蚌埠',
#  '蚌埠市',
#  '衡水',
#  '衡水市',
#  '衡阳',
#  '衡阳市',
#  '衢州',
#  '衢州市',
#  '襄樊',
#  '襄樊市',
#  '西双版纳',
#  '西双版纳傣族自治州',
#  '西宁',
#  '西宁市',
#  '西安',
#  '西安市',
#  '西藏',
#  '许昌',
#  '许昌市',
#  '贵州',
#  '贵港',
#  '贵港市',
#  '贵阳',
#  '贵阳市',
#  '贺州',
#  '贺州市',
#  '资阳',
#  '资阳市',
#  '赣州',
#  '赣州市',
#  '赤峰',
#  '赤峰市',
#  '辽宁',
#  '辽源',
#  '辽源市',
#  '辽阳',
#  '辽阳市',
#  '达州',
#  '达州市',
#  '运城',
#  '运城市',
#  '连云港',
#  '连云港市',
#  '迪庆',
#  '迪庆藏族自治州',
#  '通化',
#  '通化市',
#  '通辽',
#  '通辽市',
#  '遂宁',
#  '遂宁市',
#  '遵义',
#  '遵义市',
#  '邢台',
#  '邢台市',
#  '那曲',
#  '那曲地区',
#  '邯郸',
#  '邯郸市',
#  '邵阳',
#  '邵阳市',
#  '郑州',
#  '郑州市',
#  '郴州',
#  '郴州市',
#  '鄂尔多斯',
#  '鄂尔多斯市',
#  '鄂州',
#  '鄂州市',
#  '酒泉',
#  '酒泉市',
#  '重庆',
#  '重庆市',
#  '金华',
#  '金华市',
#  '金昌',
#  '金昌市',
#  '钦州',
#  '钦州市',
#  '铁岭',
#  '铁岭市',
#  '铜仁',
#  '铜仁地区',
#  '铜仁市',
#  '铜川',
#  '铜川市',
#  '铜陵',
#  '铜陵市',
#  '银川',
#  '银川市',
#  '锡林郭勒',
#  '锡林郭勒盟',
#  '锦州',
#  '锦州市',
#  '镇江',
#  '镇江市',
#  '长春',
#  '长春市',
#  '长沙',
#  '长沙市',
#  '长治',
#  '长治市',
#  '阜新',
#  '阜新市',
#  '阜阳',
#  '阜阳市',
#  '防城港',
#  '防城港市',
#  '阳江',
#  '阳江市',
#  '阳泉',
#  '阳泉市',
#  '阿克苏',
#  '阿克苏地区',
#  '阿勒泰',
#  '阿勒泰地区',
#  '阿坝',
#  '阿坝藏族羌族自治州',
#  '阿拉善盟',
#  '阿里',
#  '阿里地区',
#  '陇南',
#  '陇南市',
#  '陕西',
#  '随州',
#  '随州市',
#  '雅安',
#  '雅安市',
#  '青岛',
#  '青岛市',
#  '青海',
#  '鞍山',
#  '鞍山市',
#  '韶关',
#  '韶关市',
#  '马鞍山',
#  '马鞍山市',
#  '驻马店',
#  '驻马店市',
#  '鸡西',
#  '鸡西市',
#  '鹤壁',
#  '鹤壁市',
#  '鹤岗',
#  '鹤岗市',
#  '鹰潭',
#  '鹰潭市',
#  '黄冈',
#  '黄冈市',
#  '黄南',
#  '黄南藏族自治州',
#  '黄山',
#  '黄山市',
#  '黄石',
#  '黄石市',
#  '黑河',
#  '黑河市',
#  '黑龙江',
#  '黔东南',
#  '黔东南苗族侗族自治州',
#  '黔南',
#  '黔南布依族苗族自治州',
#  '黔西南',
#  '黔西南布依族苗族自治州',
#  '齐齐哈尔',
#  '齐齐哈尔市',
#  '龙岩',
#  '龙岩市'}

# %%
# 文件扫描
import glob
# JSON读取（数据集不是标准JSON所以不用自带的json库）
import jstyleson
# 集合数据结构
import collections
# 正则表达式
import re

# %%
print("扫描所有数据:")
files = glob.glob('data/*.json')
files
# Out:
# 扫描所有数据:
# ['data\\上海市确诊病例活动轨迹.json',
#  'data\\云南省确诊病例活动轨迹.json',
#  'data\\内蒙古自治区确诊病例活动轨迹.json',
#  'data\\北京市确诊病例活动轨迹.json',
#  'data\\台湾省确诊病例活动轨迹.json',
#  'data\\吉林省确诊病例活动轨迹.json',
#  'data\\四川省确诊病例活动轨迹.json',
#  'data\\天津市确诊病例活动轨迹.json',
#  'data\\宁夏回族自治区确诊病例活动轨迹.json',
#  'data\\安徽省确诊病例活动轨迹.json',
#  'data\\山东省确诊病例活动轨迹.json',
#  'data\\山西省确诊病例活动轨迹.json',
#  'data\\广东省确诊病例活动轨迹.json',
#  'data\\广西壮族自治区确诊病例活动轨迹.json',
#  'data\\新疆维吾尔自治区确诊病例活动轨迹.json',
#  'data\\江苏省确诊病例活动轨迹.json',
#  'data\\江西省确诊病例活动轨迹.json',
#  'data\\河北省确诊病例活动轨迹.json',
#  'data\\河南省确诊病例活动轨迹.json',
#  'data\\浙江省确诊病例活动轨迹.json',
#  'data\\海南省确诊病例活动轨迹.json',
#  'data\\湖南省确诊病例活动轨迹.json',
#  'data\\甘肃省确诊病例活动轨迹.json',
#  'data\\福建省确诊病例活动轨迹.json',
#  'data\\贵州省确诊病例活动轨迹.json',
#  'data\\辽宁省确诊病例活动轨迹.json',
#  'data\\重庆市确诊病例活动轨迹.json',
#  'data\\陕西省确诊病例活动轨迹.json',
#  'data\\香港特别行政区确诊病例活动轨迹.json',
#  'data\\黑龙江省确诊病例活动轨迹.json']

# %% [markdown]
# # 数据读取处理

# %%
# 市级行政区计数器
c = collections.Counter()
# 非市级计数
c_without_city = collections.Counter()
# 日期记录
dates = set()

location_to_person = {}
person_to_location = {}
graph = {}
loc_map = {}

c, c_without_city
# Out:
# (Counter(), Counter())

# %%
# 日期格式整理
def date_validator(str):
    res = re.search(r'^\d+月\d+',str)
    if res:
        month,day = map(int,res[0].split('月'))
        return (month,day,res[0]+'日')

# %%
person_counter = 0
filename='data\\浙江省确诊病例活动轨迹.json'
# for filename in files:
f = open(filename,'r',encoding='utf-8')
data = jstyleson.load(f)
affected_places = set()
print(f"{filename} 人数:{len(data)}")
for person in data:
    person_counter += 1
    entries = person.keys()
    # 数据含有轨迹及基本数据，仅提取轨迹
    paths = filter(lambda x:'轨迹' in x,entries)
    last_place = None
    for pathname in paths:
        # 部分数据格式有问题
        try:
            date = date_validator(person[pathname]['时间'])
            if date:
                dates.add(date)
            # p_name: 地点名；p_loc: 地点坐标
            for p_name, p_loc in person[pathname]['途径地点']:
                if p_name in city_list:
                    c[(p_name, p_loc)] += 1
                else:
                    c_without_city[(p_name, p_loc)] += 1
                # 统计到达过某个地点的人，每个编号表示一个人
                location_to_person.setdefault(p_name,set()).add(person_counter)
                if last_place and date and "院" not in p_name and "院" not in last_place:
                    # 创建无向图
                    affected_places.add(p_name)
                    graph.setdefault(p_name,[]).append((last_place,date))
                    graph.setdefault(last_place,[]).append((p_name,date))
                    loc_map[p_name] = p_loc

                last_place = p_name
        except:
            print('wrong')

affected_places_list = list(affected_places)
affected_places_list = affected_places_list[1:]
len(affected_places_list)
# for key in graph:
#     print(key)
#     print(' >>> ')
#     print(graph[key])
# Out:
# data\浙江省确诊病例活动轨迹.json 人数:435
# 26

# %%
graph['武汉']
# Out:
# [('兰溪', (1, 22, '1月22日')),
#  ('温州', (1, 22, '1月22日')),
#  ('温州', (1, 19, '1月19日')),
#  ('温州', (1, 18, '1月18日')),
#  ('深圳', (1, 16, '1月16日')),
#  ('嘉兴', (1, 21, '1月21日')),
#  ('椒江', (1, 23, '1月23日')),
#  ('临海', (1, 25, '1月25日')),
#  ('杭州', (1, 19, '1月19日')),
#  ('乐清', (1, 17, '1月17日')),
#  ('温州', (1, 22, '1月22日')),
#  ('乐清', (1, 22, '1月22日')),
#  ('乐清', (1, 20, '1月20日')),
#  ('温州', (1, 17, '1月17日')),
#  ('温州', (1, 22, '1月22日')),
#  ('温州', (1, 22, '1月22日')),
#  ('温州', (1, 12, '1月12日')),
#  ('温州', (1, 13, '1月13日')),
#  ('温州', (1, 21, '1月21日')),
#  ('宁波', (1, 18, '1月18日')),
#  ('宁波', (1, 21, '1月21日')),
#  ('温州', (1, 16, '1月16日')),
#  ('温州', (1, 22, '1月22日')),
#  ('温州', (1, 23, '1月23日'))]

# %%
print(sorted(dates))
# Out:
# [(1, 7, '1月7日'), (1, 11, '1月11日'), (1, 12, '1月12日'), (1, 13, '1月13日'), (1, 14, '1月14日'), (1, 15, '1月15日'), (1, 16, '1月16日'), (1, 17, '1月17日'), (1, 18, '1月18日'), (1, 19, '1月19日'), (1, 20, '1月20日'), (1, 21, '1月21日'), (1, 22, '1月22日'), (1, 23, '1月23日'), (1, 24, '1月24日'), (1, 25, '1月25日'), (1, 26, '1月26日'), (1, 27, '1月27日'), (1, 28, '1月28日'), (1, 29, '1月29日'), (1, 30, '1月30日'), (1, 31, '1月31日'), (1, 271, '1月271日'), (2, 1, '2月1日'), (2, 2, '2月2日'), (2, 3, '2月3日'), (2, 4, '2月4日'), (2, 5, '2月5日'), (2, 6, '2月6日'), (2, 7, '2月7日'), (2, 8, '2月8日'), (2, 9, '2月9日'), (2, 10, '2月10日'), (2, 11, '2月11日'), (2, 12, '2月12日'), (2, 13, '2月13日')]

# %% [markdown]
# ## 传播路径BFS

# %%
import queue

# %%
visited = set()
affected_person = set()
affected_path = []

# 从某个传播中心开始进行BFS，搜索某人可能被感染的第一个地点
q = collections.deque()
q.append(('武汉',''))
while q:
    now, before = q.popleft()
    path = f"{before}{now}-"
    # 传播路径，对所有去过该地点的人进行检查，如果到达过，说明该人可能在该地点被感染
    # 为了简化问题，我们认为某人到过出现过患者的地点则被感染，即该人可能被感染的第一个地点
    for person in location_to_person[now]:
        if person not in affected_person:
            affected_person.add(person)
            affected_path.append(f"{person}号病人可能的传播路径：{path}")
    for neighbour,date in graph[now]: 
        if neighbour not in visited:
                visited.add(neighbour)
                q.append((neighbour,path))

# %%
sorted(affected_path)
# Out:
# ['112号病人可能的传播路径：武汉-温州-',
#  '117号病人可能的传播路径：武汉-温州-',
#  '118号病人可能的传播路径：武汉-温州-',
#  '11号病人可能的传播路径：武汉-温州-',
#  '144号病人可能的传播路径：武汉-宁波-',
#  '166号病人可能的传播路径：武汉-杭州-',
#  '167号病人可能的传播路径：武汉-杭州-',
#  '170号病人可能的传播路径：武汉-宁波-',
#  '175号病人可能的传播路径：武汉-温州-',
#  '190号病人可能的传播路径：武汉-温州-',
#  '195号病人可能的传播路径：武汉-温州-',
#  '196号病人可能的传播路径：武汉-温州-',
#  '197号病人可能的传播路径：武汉-温州-',
#  '198号病人可能的传播路径：武汉-温州-',
#  '205号病人可能的传播路径：武汉-温州-',
#  '206号病人可能的传播路径：武汉-温州-',
#  '207号病人可能的传播路径：武汉-嘉兴-',
#  '210号病人可能的传播路径：武汉-温州-诸暨-',
#  '212号病人可能的传播路径：武汉-',
#  '219号病人可能的传播路径：武汉-杭州-',
#  '228号病人可能的传播路径：武汉-温州-湖北-',
#  '229号病人可能的传播路径：武汉-温州-湖北-',
#  '231号病人可能的传播路径：武汉-杭州-',
#  '232号病人可能的传播路径：武汉-杭州-',
#  '243号病人可能的传播路径：武汉-宁波-',
#  '244号病人可能的传播路径：武汉-宁波-',
#  '245号病人可能的传播路径：武汉-宁波-',
#  '25号病人可能的传播路径：武汉-温州-',
#  '260号病人可能的传播路径：武汉-',
#  '263号病人可能的传播路径：武汉-',
#  '270号病人可能的传播路径：武汉-温州-',
#  '272号病人可能的传播路径：武汉-',
#  '273号病人可能的传播路径：武汉-',
#  '277号病人可能的传播路径：武汉-',
#  '284号病人可能的传播路径：武汉-',
#  '285号病人可能的传播路径：武汉-',
#  '301号病人可能的传播路径：武汉-杭州-',
#  '302号病人可能的传播路径：武汉-',
#  '303号病人可能的传播路径：武汉-杭州-',
#  '304号病人可能的传播路径：武汉-杭州-',
#  '30号病人可能的传播路径：武汉-温州-',
#  '312号病人可能的传播路径：武汉-宁波-',
#  '313号病人可能的传播路径：武汉-宁波-',
#  '327号病人可能的传播路径：武汉-宁波-',
#  '328号病人可能的传播路径：武汉-宁波-',
#  '329号病人可能的传播路径：武汉-宁波-',
#  '334号病人可能的传播路径：武汉-宁波-',
#  '343号病人可能的传播路径：武汉-温州-',
#  '351号病人可能的传播路径：武汉-',
#  '354号病人可能的传播路径：武汉-',
#  '357号病人可能的传播路径：武汉-',
#  '358号病人可能的传播路径：武汉-',
#  '363号病人可能的传播路径：武汉-',
#  '364号病人可能的传播路径：武汉-温州-',
#  '365号病人可能的传播路径：武汉-温州-',
#  '367号病人可能的传播路径：武汉-',
#  '371号病人可能的传播路径：武汉-温州-',
#  '377号病人可能的传播路径：武汉-',
#  '378号病人可能的传播路径：武汉-',
#  '379号病人可能的传播路径：武汉-',
#  '380号病人可能的传播路径：武汉-温州-',
#  '382号病人可能的传播路径：武汉-温州-',
#  '383号病人可能的传播路径：武汉-',
#  '388号病人可能的传播路径：武汉-',
#  '390号病人可能的传播路径：武汉-',
#  '39号病人可能的传播路径：武汉-',
#  '425号病人可能的传播路径：武汉-温州-',
#  '427号病人可能的传播路径：武汉-',
#  '428号病人可能的传播路径：武汉-温州-',
#  '431号病人可能的传播路径：武汉-温州-',
#  '432号病人可能的传播路径：武汉-',
#  '433号病人可能的传播路径：武汉-温州-',
#  '434号病人可能的传播路径：武汉-',
#  '45号病人可能的传播路径：武汉-温州-台州-',
#  '46号病人可能的传播路径：武汉-温州-台州-',
#  '50号病人可能的传播路径：武汉-杭州-广东省-',
#  '66号病人可能的传播路径：武汉-温州-台州-',
#  '67号病人可能的传播路径：武汉-温州-台州-',
#  '99号病人可能的传播路径：武汉-温州-']

# %% [markdown]
# ## 传播热点BFS

# %%
visited = set()
affected_person = set()
hotspots = collections.Counter()

# 从某个传播中心开始，向外做BFS，统计到达过该地点的人数，人数越多，说明该地点为传播热点地区
# 使用BFS的原因：基于病毒是从某个传播中心开始，向外网状扩张的
q = collections.deque()
q.append(('武汉',''))
while q:
    now, before = q.popleft()
    path = f"{before}{now}-"
    # 对到达过该地点的患者人数做统计，如果到达过该地点的患者人数较多，则认为该地点为传播热点地区
    for person in location_to_person[now]:
        if person not in affected_person:
            hotspots[now] += 1
    # 对所有邻接点做BFS
    for neighbour,date in graph[now]: 
        if neighbour not in visited:
                visited.add(neighbour)
                q.append((neighbour,path))

# %%
list(map(lambda x:f"热点传播地区:{x[0]} 被感染人数:{x[1]}",hotspots.most_common(10)))
# Out:
# ['热点传播地区:武汉 被感染人数:50',
#  '热点传播地区:温州 被感染人数:39',
#  '热点传播地区:宁波 被感染人数:13',
#  '热点传播地区:湖北 被感染人数:12',
#  '热点传播地区:杭州 被感染人数:11',
#  '热点传播地区:台州 被感染人数:8',
#  '热点传播地区:广州 被感染人数:4',
#  '热点传播地区:乐清 被感染人数:3',
#  '热点传播地区:哈尔滨 被感染人数:3',
#  '热点传播地区:湖北省随州市 被感染人数:3']

# %%
# 列出前十个传播热点地区
def getHotPot(x):
    if "院" not in x[0]:
        return f"热点传播地区:{x[0]} 被感染人数:{x[1]}";
    else:
        return None

list(map(getHotPot,hotspots.most_common(25)))
# Out:
# ['热点传播地区:武汉 被感染人数:50',
#  '热点传播地区:温州 被感染人数:39',
#  '热点传播地区:宁波 被感染人数:13',
#  '热点传播地区:湖北 被感染人数:12',
#  '热点传播地区:杭州 被感染人数:11',
#  '热点传播地区:台州 被感染人数:8',
#  '热点传播地区:广州 被感染人数:4',
#  '热点传播地区:乐清 被感染人数:3',
#  '热点传播地区:哈尔滨 被感染人数:3',
#  '热点传播地区:湖北省随州市 被感染人数:3',
#  '热点传播地区:杭州桐庐 被感染人数:3',
#  '热点传播地区:深圳 被感染人数:2',
#  '热点传播地区:嘉兴 被感染人数:2',
#  '热点传播地区:上海 被感染人数:2',
#  '热点传播地区: 湖北荆门市 被感染人数:2',
#  '热点传播地区:诸暨 被感染人数:2',
#  '热点传播地区:广东省 被感染人数:2',
#  '热点传播地区:湖北荆州 被感染人数:2',
#  '热点传播地区:湖北随州 被感染人数:2',
#  '热点传播地区:重庆 被感染人数:2',
#  '热点传播地区:兰溪 被感染人数:1',
#  '热点传播地区:椒江 被感染人数:1',
#  '热点传播地区:临海 被感染人数:1',
#  '热点传播地区:金华市 被感染人数:1',
#  '热点传播地区:湖南 被感染人数:1']

# %% [markdown]
# ## 管制区域DFS

# %%
visited = set()

high_area,mid_area = [],[]
hotspots = collections.Counter()
threshold_high = 20
threshold_mid = 3
cnt = 0

def dfs(now,before):
#     global cnt
#     cnt = cnt + 1
    visited.add(now)
    path = f"{before}{now}-"
    # 计算该地点热点值，由于需要划分管制区域，为了得到较好的管制效果，
    # 对所有到过该地点的人都做统计，以实现管制区域精细化以及效果最大化
    for person in location_to_person[now]:
        hotspots[now] += 1

    if now not in city_list:
        if(hotspots[now] >= threshold_high):
            high_area.append(now)
        elif(hotspots[now] >= threshold_mid):
            mid_area.append(now)

    for neighbour,date in graph[now]: 
        if neighbour not in visited:
                dfs(neighbour,path)

dfs('武汉','')
for n in affected_places_list:
    if n not in visited:
        dfs(n, '')
        cnt = cnt + 1
print("高风险地区:",high_area)
print("中风险地区:",mid_area)
cnt
# Out:
# 高风险地区: []
# 中风险地区: ['湖北省随州市', '杭州桐庐', '乐清', '浦江县', '新加坡樟宜机场', '杭州萧山机场']
# 7

# %% [markdown]
# ## 连通分量DFS

# %%
import folium
import random

visited = set()
connected = []
connected.append([])

hotspots = collections.Counter()
cnt = 0
nofind = 0

mm = folium.Map(location=[45.75,126.65],zoom_start=11)

def dfs(now,before,component):
    global nofind
    visited.add(now)
    # 记录该连通分量中的地点
    if now in loc_map:
        component.append(loc_map[now])
    else:
        nofind = nofind + 1
    # 继续进行DFS
    for neighbour,date in graph[now]: 
        if neighbour not in visited:
            dfs(neighbour,path,component)

# 对图进行DFS
dfs('武汉','', connected[0])
for n in affected_places_list:
    # 对其他的联通分量继续进行DFS
    if n not in visited:
        cnt = cnt + 1
        connected.append([])
        dfs(n, '', connected[cnt])
        
print('联通分量总数：'+str(cnt))

nnnn = 0
max = 0
maxid = 0
precolor = ['white', 'lightred', 'beige', 'green', 'cadetblue', 'lightgray', 'purple', 'darkpurple', 'lightblue', 'pink', 'gray', 'darkgreen', 'darkred', 'lightgreen', 'blue', 'red', 'black', 'orange', 'darkblue']
print(len(precolor))
      
# 数据可视化，每个联通分量用一个颜色表示
for cmp in connected:
    colorid_num = random.randint(1118481,16777215)
    colorid_num = hex(colorid_num)
    colorid_num = str(colorid_num)[2:]
    if len(cmp) > max:
        max = len(cmp)
        maxid = nnnn
    colorid = str('#') + str(colorid_num)
    nnnn = nnnn + 1
    if nnnn > 18:
        nnnn = 18
    for p in cmp:
        if not p == '':
            longitude,latitude = map(float,p.split(','))
            folium.CircleMarker(
            location=[latitude, longitude],
            radius=5,
            popup='Laurelhurst Park',
            color=colorid,
            fill=True,
            fill_color=colorid
            ).add_to(mm)
        
print('最大的联通分量中共有'+str(max)+'个节点，可认为这些人来自同源的新冠病例，零星的连通分量可能属于外来输入病例或得到严格控制的病例')
# print(connected[maxid])
mm
# Out:
# 联通分量总数：7
# 19
# 最大的联通分量中共有13个节点，可认为这些人来自同源的新冠病例，零星的连通分量可能属于外来输入病例或得到严格控制的病例
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f8fc9edf1ceb47c4a6e3b5d15ef4352b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f8fc9edf1ceb47c4a6e3b5d15ef4352b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f8fc9edf1ceb47c4a6e3b5d15ef4352b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f8fc9edf1ceb47c4a6e3b5d15ef4352b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B45.75%2C%20126.65%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## 传播高峰期推算DFS

# %%
dates = [(1, 3, '1月3日'), (1, 4, '1月4日'), (1, 6, '1月6日'), (1, 7, '1月7日'), (1, 8, '1月8日'), (1, 9, '1月9日'), (1, 10, '1月10日'), (1, 11, '1月11日'), (1, 12, '1月12日'), (1, 13, '1月13日'), (1, 14, '1月14日'), (1, 15, '1月15日'), (1, 16, '1月16日'), (1, 17, '1月17日'), (1, 18, '1月18日'), (1, 19, '1月19日'), (1, 20, '1月20日'), (1, 21, '1月21日'), (1, 22, '1月22日'), (1, 23, '1月23日'), (1, 24, '1月24日'), (1, 25, '1月25日'), (1, 26, '1月26日'), (1, 27, '1月27日'), (1, 28, '1月28日'), (1, 29, '1月29日'), (1, 30, '1月30日'), (1, 31, '1月31日'), (2, 1, '2月1日'), (2, 2, '2月2日'), (2, 3, '2月3日'), (2, 4, '2月4日'), (2, 5, '2月5日'), (2, 6, '2月6日'), (2, 7, '2月7日'), (2, 8, '2月8日'), (2, 9, '2月9日'), (2, 10, '2月10日'), (2, 11, '2月11日'), (2, 12, '2月12日'), (2, 13, '2月13日'), (2, 14, '2月14日'), (2, 15, '2月15日'), (2, 16, '2月16日'), (2, 17, '2月17日'), (2, 18, '2月18日'), (2, 19, '2月19日'), (2, 21, '2月21日'), (2, 26, '2月26日'), (3, 4, '3月4日')]

visited = set()
affected_person = set()
high_area,mid_area = [],[]
hotspots = collections.Counter()

def dfs(now,before,date):
    visited.add(now)
    path = f"{before}{now}-"
    # 统计
    for person in location_to_person[now]:
        if person not in affected_person:
            affected_person.add(person)

    if now not in city_list:
        if(hotspots[now] >= threshold_high):
            high_area.append(now)
        elif(hotspots[now] >= threshold_mid):
            mid_area.append(now)

    for neighbour,edge_date in graph[now]:
        # 遍历图，对指定日期之前的确诊人数做统计
        if edge_date[:2] <= date:
            if neighbour not in visited:
                    dfs(neighbour,path,date)

process = []
increment = []
count = 0
for date in dates:
    visited = set()
    dfs('武汉','',date[:2])
    now = len(affected_person)
    print(f"{date[2]}累计感染人数：{now}，较前日新增：{now-count}")
    process.append(now)
    increment.append(now - count)
    count = now

# process, increment, len(process)
# Out:
# 1月3日累计感染人数：25，较前日新增：25
# 1月4日累计感染人数：25，较前日新增：0
# 1月6日累计感染人数：25，较前日新增：0
# 1月7日累计感染人数：25，较前日新增：0
# 1月8日累计感染人数：25，较前日新增：0
# 1月9日累计感染人数：25，较前日新增：0
# 1月10日累计感染人数：25，较前日新增：0
# 1月11日累计感染人数：25，较前日新增：0
# 1月12日累计感染人数：53，较前日新增：28
# 1月13日累计感染人数：53，较前日新增：0
# 1月14日累计感染人数：54，较前日新增：1
# 1月15日累计感染人数：54，较前日新增：0
# 1月16日累计感染人数：56，较前日新增：2
# 1月17日累计感染人数：57，较前日新增：1
# 1月18日累计感染人数：68，较前日新增：11
# 1月19日累计感染人数：78，较前日新增：10
# 1月20日累计感染人数：78，较前日新增：0
# 1月21日累计感染人数：78，较前日新增：0
# 1月22日累计感染人数：79，较前日新增：1
# 1月23日累计感染人数：79，较前日新增：0
# 1月24日累计感染人数：79，较前日新增：0
# 1月25日累计感染人数：79，较前日新增：0
# 1月26日累计感染人数：79，较前日新增：0
# 1月27日累计感染人数：79，较前日新增：0
# 1月28日累计感染人数：79，较前日新增：0
# 1月29日累计感染人数：79，较前日新增：0
# 1月30日累计感染人数：79，较前日新增：0
# 1月31日累计感染人数：79，较前日新增：0
# 2月1日累计感染人数：79，较前日新增：0
# 2月2日累计感染人数：79，较前日新增：0
# 2月3日累计感染人数：79，较前日新增：0
# 2月4日累计感染人数：79，较前日新增：0
# 2月5日累计感染人数：79，较前日新增：0
# 2月6日累计感染人数：79，较前日新增：0
# 2月7日累计感染人数：79，较前日新增：0
# 2月8日累计感染人数：79，较前日新增：0
# 2月9日累计感染人数：79，较前日新增：0
# 2月10日累计感染人数：79，较前日新增：0
# 2月11日累计感染人数：79，较前日新增：0
# 2月12日累计感染人数：79，较前日新增：0
# 2月13日累计感染人数：79，较前日新增：0
# 2月14日累计感染人数：79，较前日新增：0
# 2月15日累计感染人数：79，较前日新增：0
# 2月16日累计感染人数：79，较前日新增：0
# 2月17日累计感染人数：79，较前日新增：0
# 2月18日累计感染人数：79，较前日新增：0
# 2月19日累计感染人数：79，较前日新增：0
# 2月21日累计感染人数：79，较前日新增：0
# 2月26日累计感染人数：79，较前日新增：0
# 3月4日累计感染人数：79，较前日新增：0

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,50)

fig,ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x,process,'g-')
ax2.plot(x,increment,'b-')

ax1.set_xlabel('days')
ax1.set_ylabel('Confirmed cases',color = 'g')
ax2.set_ylabel('New cases',color = 'b')

plt.show()

# %% [markdown]
# # 结果可视化

# %%
# 图像可视化
from folium.plugins import HeatMap

# %% [markdown]
# ## 患者活动轨迹热点图(风险区域划分)

# %%
heat_data = []
# 最频繁出现的地点
# print(c_without_city.most_common(100))
for place in c_without_city.most_common(100):
    try:
        longitude,latitude = map(float,place[0][1].split(','))
        heat_data.append([latitude,longitude,place[1]])
    except:
        pass
# print(heat_data)
# 武汉市及附近
m = folium.Map(location=[45.75,126.65],zoom_start=11)
# 添加热点图层
HeatMap(heat_data).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_71ece0ba20b444158adf13fb8f8a0c08%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_71ece0ba20b444158adf13fb8f8a0c08%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_71ece0ba20b444158adf13fb8f8a0c08%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_71ece0ba20b444158adf13fb8f8a0c08%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...
